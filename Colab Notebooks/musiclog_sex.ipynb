# %%
import cv2
import pandas as pd

# %%
data = pd.read_csv('transactions.csv')

# %%
data.head(20)
# Out:
#     user_id  song_id  ...                entry listen
# 0         5        5  ...      online-playlist      0
# 1         7        7  ...                 song      1
# 2        14       14  ...  song-based-playlist      0
# 3        22       22  ...        local-library      0
# 4        24       24  ...      online-playlist      0
# 5        26       26  ...                 song      1
# 6        27       27  ...      online-playlist      0
# 7        28       28  ...      online-playlist      1
# 8        32       32  ...        local-library      1
# 9        36       36  ...        local-library      1
# 10       37       37  ...                album      0
# 11       38       38  ...  song-based-playlist      0
# 12       41       41  ...          listen-with      1
# 13       43       18  ...        local-library      1
# 14       45       44  ...          listen-with      0
# 15       46       45  ...      online-playlist      0
# 16       47       46  ...       local-playlist      1
# 17       49       48  ...       local-playlist      1
# 18       51       50  ...                album      1
# 19       57       56  ...        local-library      1
#
# [20 rows x 6 columns]

# %%
data.tail(10)
# Out:
#          user_id  song_id  ...                entry listen
# 1819845     6936     6652  ...  top-hits-for-artist      0
# 1819846    23120      514  ...      online-playlist      1
# 1819847     5003     2582  ...      online-playlist      1
# 1819848    10758     6623  ...        local-library      1
# 1819849     8737     1050  ...      online-playlist      1
# 1819850     6273     6415  ...        local-library      0
# 1819851     4505     8831  ...        local-library      0
# 1819852      682     1921  ...                radio      0
# 1819853    12056     7586  ...  top-hits-for-artist      0
# 1819854     9505      889  ...        local-library      1
#
# [10 rows x 6 columns]

# %%
data[data.user_id == 7]
# Out:
#          user_id  song_id  ...                entry listen
# 1              7        7  ...                 song      1
# 238            7      551  ...  song-based-playlist      0
# 5723           7     4611  ...       local-playlist      1
# 26790          7     1728  ...       local-playlist      1
# 31803          7     2175  ...       local-playlist      0
# ...          ...      ...  ...                  ...    ...
# 1771933        7     4222  ...      online-playlist      0
# 1783510        7      609  ...      online-playlist      0
# 1784076        7     2770  ...      online-playlist      0
# 1787825        7      131  ...       local-playlist      1
# 1798654        7      368  ...        local-library      0
#
# [224 rows x 6 columns]

# %%
data.isnull()
# Out:
#         user_id  song_id  rec_loc  rec_screen  entry  listen
# 0         False    False    False       False  False   False
# 1         False    False    False       False  False   False
# 2         False    False    False       False  False   False
# 3         False    False    False       False  False   False
# 4         False    False    False       False  False   False
# ...         ...      ...      ...         ...    ...     ...
# 134096    False    False    False       False  False   False
# 134097    False    False    False       False  False   False
# 134098    False    False    False       False  False   False
# 134099    False    False    False       False  False   False
# 134100    False    False    False       False   True    True
#
# [134101 rows x 6 columns]

# %%
data.fillna(0)
# Out:
#         user_id  song_id  ...                entry listen
# 0             5        5  ...      online-playlist    0.0
# 1             7        7  ...                 song    1.0
# 2            14       14  ...  song-based-playlist    0.0
# 3            22       22  ...        local-library    0.0
# 4            24       24  ...      online-playlist    0.0
# ...         ...      ...  ...                  ...    ...
# 134096     6481      518  ...                album    0.0
# 134097     4020     8239  ...                album    0.0
# 134098     8473     3756  ...        local-library    1.0
# 134099    11439     2873  ...       local-playlist    1.0
# 134100    16683     1296  ...                    0    0.0
#
# [134101 rows x 6 columns]

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')

# %%
train_data[train_data.user_id == 13827]
# Out:
#    user_id  city  age  reg_method  reg_date   ex_date  gender
# 0    13827    14   29           9  20130112  20180203  female

# %%
test_data[test_data.user_id == 13517]
# Out:
# Empty DataFrame
# Columns: [user_id, city, age, reg_method, reg_date, ex_date, gender]
# Index: []

# %%
train_data['gender'].value_counts()
# Out:
# male      3600
# female    3400
# Name: gender, dtype: int64

# %%
test_data['gender'].value_counts()
# Out:
# Series([], Name: gender, dtype: int64)

# %%
train_data['reg_method'].value_counts()
# Out:
# 9     3542
# 3     1813
# 7      953
# 4      687
# 13       5
# Name: reg_method, dtype: int64
