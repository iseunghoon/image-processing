# %% [markdown]
# 2.0 으로 고치기
# 진단서 : 176
# 입퇴원 확인서:  55
# 영수증:  69
# 의무기록:  81
# 수술기록지:  68
# ```
# # 코드로 형식 지정됨
# ```

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
import glob
import os
import cv2

# %%
for i,name in enumerate(glob.glob('/content/medi2/confirm/*')):
  os.remove(name)

# %%
class_name = ['confirm','inout','receipt','record','surgery']
str(class_name[0])
lists = glob.glob('/content/drive/My Drive/medi/'+ str(class_name[0])+'/*')
len(lists)
# Out:
# 176

# %%
class_name = ['confirm','inout','receipt','record','surgery']
path = '/content/drive/My Drive/medi/'+ str(class_name[0]) + '/*'
print(path)
lists = glob.glob(path)
len(lists)
# Out:
# /content/drive/My Drive/medi/confirm/*
# 176

# %%
import numpy as np

# 랜덤시드 고정시키기
np.random.seed(5)

from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
class_name = ['confirm','inout','receipt','record','surgery']
# 데이터셋 불러오기
for j in range(5):
  lists = glob.glob('/content/drive/My Drive/medi/'+ str(class_name[j])+'/*')
  for name in lists: 
    data_aug_gen = ImageDataGenerator(rescale=1./255, 
                                    rotation_range=15,
                                    width_shift_range=0.1,
                                    height_shift_range=0.1,
                                    shear_range=0.5,
                                    zoom_range=[0.8, 1.2],
                                    horizontal_flip=True,
                                    vertical_flip=True,
                                    fill_mode='nearest')
                                   
    img = load_img(name)
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    i = 0

# 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야합니다.
    for batch in data_aug_gen.flow(x, batch_size=1, save_to_dir='/content/medi2/'+str(class_name[j])+'/', save_prefix= class_name[j], save_format='png'):
        i += 1
        if i > 2: 
          break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-167b1435085c> in <module>()
#      20                                     fill_mode='nearest')
#      21
# ---> 22     img = load_img(name)
#      23     x = img_to_array(img)
#      24     x = x.reshape((1,) + x.shape)
#
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     108         raise ImportError('Could not import PIL.Image. '
#     109                           'The use of `load_img` requires PIL.')
# --> 110     img = pil_image.open(path)
#     111     if color_mode == 'grayscale':
#     112         if img.mode != 'L':
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2773         exclusive_fp = True
#    2774
# -> 2775     prefix = fp.read(16)
#    2776
#    2777     preinit()
#
# ...

# %%
lists = glob.glob('/content/medi2/confirm/*')
len(lists)
# Out:
# 3871

# %%
lists = glob.glob('/content/medi2/'+ str(class_name[1])+'')

# %%
lists
# Out:
# ['/content/medi2/inout']

# %%
lists = glob.glob('/content/drive/My Drive/medi/surgery/*')
for name in lists: 
    data_aug_gen = ImageDataGenerator(rescale=1./255, 
                                    rotation_range=15,
                                    width_shift_range=0.1,
                                    height_shift_range=0.1,
                                    shear_range=0.5,
                                    zoom_range=[0.8, 1.2],
                                    horizontal_flip=True,
                                    vertical_flip=True,
                                    fill_mode='nearest')
                                   
    img = load_img(name, color_mode="grayscale", target_size=(256,256))
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    i = 0

# 이 for는 무한으로 반복되기 때문에 우리가 원하는 반복횟수를 지정하여, 지정된 반복횟수가 되면 빠져나오도록 해야합니다.
    for batch in data_aug_gen.flow(x, batch_size=1, save_to_dir='/content/medi2/surgery', save_prefix= 'surgery', save_format='png'):
        i += 1
        if i > 10: 
          break

# %%
len(glob.glob('/content/medi2/confirm/*'))
# Out:
# 688

# %%
img = load_img('/content/medi2/inout/inout_0_1603.png', color_mode="grayscale", target_size=(256,256))
x = img_to_array(img)
x = x.reshape((1,) + x.shape)

# %%
x.shape
# Out:
# (1, 100, 100, 1)

# %%
img = cv2.imread('/content/medi2/inout/inout_0_1042.png')
img.shape
img[0]
# Out:
# array([[250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
#        [249, 249, 249],
#        [250, 250, 250],
#        [253, 253, 253],
#        [250, 250, 250],
#        [245, 245, 245],
#        [245, 245, 245],
#        [242, 242, 242],
#        [252, 252, 252],
#        [239, 239, 239],
#        [240, 240, 240],
#        [249, 249, 249],
#        [250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
#        [250, 250, 250],
# ...
