# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
cudir = os.getcwd()

# %%
print(cudir)
# Out:
# /content

# %%
a = os.listdir('/content/drive/My Drive/sulhyun')

# %%
len(a)
# Out:
# 50

# %%
imglist=[]
for i, name in enumerate(a):
  print(name)
  img  =  cv2.imread(name)
  imglist.append(img)
# Out:
# 1.170917_AOA_%EC%84%A4%ED%98%84_%EC%82%B4%EC%9D%B8%EC%9E%90%EC%9D%98_%EA%B8%B0%EC%96%B5%EB%B2%95_%EB%AC%B4%EB%8C%80%EC%9D%B8%EC%82%AC_04.jpg
# 3.c91d2742b4ee205f9b026cc9479a9b56.jpg
# 2.style_5c1af10b7576a.jpg
# 4.180503_AOA_%EC%84%A4%ED%98%84_%EB%B0%B1%EC%83%81%EC%98%88%EC%88%A0%EB%8C%80%EC%83%81_%283%29.jpg
# 5.16.05.24_KBS_1TV_%EC%97%B4%EB%A6%B0%EC%9D%8C%EC%95%85%ED%9A%8C_AOA_7.jpg
# 6.htm_20190729104652375824.jpg
# 7.738426186da3ac1b28d20bae80893bfd.jpg
# 8.03.17762066.1.jpg
# 9.93324252.2.jpg
# 10.2018121601565_0.jpg
# 11.30000615587_700.jpg
# 12.03.16857772.1.jpg
# 13.1.jpg
# 14.03.16958406.1.jpg
# 15.30000612876_700.jpg
# 16.99067346.2.jpg
# 18.8aac88f77d05c6b82cfa727d1e7a49c0.jpg
# 17.style_5c1af11a0c4bf.jpg
# 20.160911_%EB%8F%99%ED%83%84_%EC%97%94%ED%84%B0%EC%8B%9D%EC%8A%A4_%EC%84%A4%ED%98%84_%ED%8C%AC%EC%8B%B8%EC%9D%B8%ED%9A%8C.jpg
# 19.20160819222709571.jpg
# 21.1VS4V0HPMT_1.jpg
# 22.20180319001047295_1521424194_1.jpg
# 23.312596_387772_2244.jpg
# 24.58199_39361_246.jpg
# ...

# %%
a[0]
# Out:
# '1.170917_AOA_%EC%84%A4%ED%98%84_%EC%82%B4%EC%9D%B8%EC%9E%90%EC%9D%98_%EA%B8%B0%EC%96%B5%EB%B2%95_%EB%AC%B4%EB%8C%80%EC%9D%B8%EC%82%AC_04.jpg'

# %%
im = cv2.imread(a[0])

# %%
import glob

# %%
imgl = glob.glob('/content/drive/My Drive/sulhyun/*.jpg')

# %%
img_list = []
img_label = []
for i, name in enumerate(imgl):
  img = cv2.imread(name)
  img_resize = cv2.resize(img,(350,350))
  img_list.append(img_resize)
  img_label.append(i)

# %%
list_array = np.array(img_list)

# %%
list_array.shape
# Out:
# (50, 350, 350, 3)

# %%
plt.figure(figsize=(16,16))
for i in range(5):
  print('im %d' % i)
  plt.subplot(2, 3, i+1)
  plt.imshow(cv2.cvtColor(list_array[i], cv2.COLOR_BGR2RGB))
# Out:
# im 0
# im 1
# im 2
# im 3
# im 4

# %%
os.mkdir('/content/drive/My Drive/new_folder')

# %%
os.rmdir('/content/drive/My Drive/new_folder')

# %%
imgl[0]
# Out:
# '/content/drive/My Drive/sulhyun/1.170917_AOA_%EC%84%A4%ED%98%84_%EC%82%B4%EC%9D%B8%EC%9E%90%EC%9D%98_%EA%B8%B0%EC%96%B5%EB%B2%95_%EB%AC%B4%EB%8C%80%EC%9D%B8%EC%82%AC_04.jpg'

# %%
img = cv2.imread(imgl[0])

# %%
img.shape
# Out:
# (626, 442, 3)

# %%
s = 22
cv2.imwrite('/content/sshh/sdsd{}.jpg'.format(s), img)
# Out:
# True

# %% [markdown]
# 이미지 파일 크기 변환해서 저장하기

# %%
for i, name in enumerate(imgl):
  img = cv2.imread(name)
  img_resize = cv2.resize(img, (350,350))
  cv2.imwrite('/content/sshh/resize_{}.jpg'.format(i), img_resize)

# %% [markdown]
# 파일 이름 한번에 바꾸기

# %%
for i, name in enumerate(os.listdir('/content/sh')):
  path = os.path.join('/content/sh', name)
  os.rename(path, '/content/sh/sh_{}'.format(i))

# %%
os.rename('/content/drive/My Drive/sulhyun', '/content/drive/My Drive/설현')

# %%
os.listdir('/content/sh')
# Out:
# ['resize_41.jpg',
#  'resize_7.jpg',
#  'resize_22.jpg',
#  'resize_30.jpg',
#  'resize_20.jpg',
#  'resize_42.jpg',
#  'resize_39.jpg',
#  'resize_3.jpg',
#  'resize_5.jpg',
#  'resize_16.jpg',
#  'resize_25.jpg',
#  'resize_33.jpg',
#  'resize_27.jpg',
#  '.ipynb_checkpoints',
#  'resize_11.jpg',
#  'resize_17.jpg',
#  'resize_4.jpg',
#  'resize_6.jpg',
#  'resize_23.jpg',
#  'resize_47.jpg',
#  'resize_19.jpg',
#  'resize_13.jpg',
#  'resize_14.jpg',
#  'resize_32.jpg',
#  'resize_12.jpg',
#  'resize_18.jpg',
#  'resize_43.jpg',
#  'resize_0.jpg',
#  'resize_48.jpg',
#  'resize_34.jpg',
#  'resize_29.jpg',
#  'resize_9.jpg',
#  'resize_24.jpg',
#  'resize_44.jpg',
#  'resize_38.jpg',
#  'resize_1.jpg',
#  'resize_26.jpg',
#  'resize_10.jpg',
#  'resize_45.jpg',
#  'resize_46.jpg',
#  'resize_49.jpg',
#  'resize_37.jpg',
#  'resize_28.jpg',
#  'resize_36.jpg',
#  'resize_2.jpg',
#  'resize_40.jpg',
#  'resize_8.jpg',
#  'resize_35.jpg',
#  'resize_31.jpg',
#  'resize_15.jpg',
# ...
