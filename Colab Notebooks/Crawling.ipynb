# %%
print("hello")
# Out:
# hello

# %%
# !pip install bs4

# %%
#!/usr/bin/env python3
# Anchor extraction from HTML document
from bs4 import BeautifulSoup
from urllib.request import urlopen

response = urlopen('https://www.naver.com/')
soup = BeautifulSoup(response, 'html.parser')
for anchor in soup.select("span.ah_k"):
    print(anchor.get_text())

# %%
# !pip install google_images_download

# %%
from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation

arguments = {"keywords":"", "limit":50, "print_urls":True}
paths = response.download(arguments)   #passing the arguments to the function
print(paths)   #printing absolute paths of the downloaded images
# Out:
# Item no.: 1 --> Item name = lee
# Evaluating...
# Starting Download...
#
#
# Unfortunately all 50 could not be downloaded because some images were not downloadable. 0 is all we got for this search filter!
#
# Errors: 0
#
# ({'lee': []}, 0)

# %%
from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation

arguments = {"keywords":"의료영수증","limit":50,"print_urls":True,"format": "jpg"}   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print(paths)   #printing absolute paths of the downloaded images
# Out:
# Item no.: 1 --> Item name = \uc758\ub8cc\uc601\uc218\uc99d
# Evaluating...
# Starting Download...
#
#
# Unfortunately all 50 could not be downloaded because some images were not downloadable. 0 is all we got for this search filter!
#
# Errors: 0
#
#
# Item no.: 2 --> Item name = \uc9c4\ub2e8\uc11c
# Evaluating...
# Starting Download...
#
#
# Unfortunately all 50 could not be downloaded because some images were not downloadable. 0 is all we got for this search filter!
#
# Errors: 0
#
#
# Item no.: 3 --> Item name = \uc758\ubb34\uae30\ub85d\uc9c0
# Evaluating...
# Starting Download...
#
#
# Unfortunately all 50 could not be downloaded because some images were not downloadable. 0 is all we got for this search filter!
#
# Errors: 0
#
#
# Item no.: 4 --> Item name = \uc785\ud1f4\uc6d0\ud655\uc778\uc11c
# Evaluating...
# Starting Download...
#
#
# Unfortunately all 50 could not be downloaded because some images were not downloadable. 0 is all we got for this search filter!
#
# Errors: 0
#
# ...

# %%
from google.colab import files
files.download('downloads')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-30-04371db166cf> in <module>()
#       1 from google.colab import files
# ----> 2 files.download('downloads')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     176       'port': port,
#     177       'path': _os.path.abspath(filename),
# --> 178       'name': _os.path.basename(filename),
#     179   })
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# ...

# %%
from google.colab import files
files.download('/content/downloads/설현')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-8-15868e28da99> in <module>()
#       1 from google.colab import files
# ----> 2 files.download('/content/downloads/설현')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     176       'port': port,
#     177       'path': _os.path.abspath(filename),
# --> 178       'name': _os.path.basename(filename),
#     179   })
#
# /usr/local/lib/python3.6/dist-packages/google/colab/output/_js.py in eval_js(script, ignore_result)
#      37   if ignore_result:
#      38     return
# ---> 39   return _message.read_reply_from_input(request_id)
#      40
#      41
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     104         reply.get('colab_msg_id') == message_id):
#     105       if 'error' in reply:
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import requests

# %%
def get_soup(url,header):
    return BeautifulSoup(urlopen(urllib.request(url,headers=header)),'html.parser')    

def main(args):
    query = "typical face"
    query = query.split()
    query = '+'.join(query)
    url = "https://www.google.co.in/search?q="+query+"&source=lnms&tbm=isch"
    headers = {}
    headers['User-Agent'] = "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36"
    soup = get_soup(url, headers)
    for a in soup.find_all("img", {"class": "rg_i"}):
        wget.download(a.attrs["data-iurl"], a.attrs["data-iid"])


if __name__ == '__main__':
    from sys import argv
    try:
        main(argv)
    except KeyboardInterrupt:
        pass
    sys.exit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-c14ab681fb38> in <module>()
#      17     from sys import argv
#      18     try:
# ---> 19         main(argv)
#      20     except KeyboardInterrupt:
#      21         pass
#
# <ipython-input-11-c14ab681fb38> in main(args)
#       9     headers = {}
#      10     headers['User-Agent'] = "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36"
# ---> 11     soup = get_soup(url, headers)
#      12     for a in soup.find_all("img", {"class": "rg_i"}):
#      13         wget.download(a.attrs["data-iurl"], a.attrs["data-iid"])
#
# <ipython-input-11-c14ab681fb38> in get_soup(url, header)
#       1 def get_soup(url,header):
# ----> 2     return BeautifulSoup(urlopen(urllib.request(url,headers=header)),'html.parser')
#       3
#       4 def main(args):
# ...

# %%
# !pip install icrawler

# %%
from icrawler.builtin import GoogleImageCrawler

google_crawler = GoogleImageCrawler(storage={'root_dir': '/content/ss'})
google_crawler.crawl(keyword='cat', max_num=100)
# Out:
# 2020-03-03 09:08:46,471 - INFO - icrawler.crawler - start crawling...
# 2020-03-03 09:08:46,473 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2020-03-03 09:08:46,474 - INFO - feeder - thread feeder-001 exit
# 2020-03-03 09:08:46,474 - INFO - icrawler.crawler - starting 1 parser threads...
# 2020-03-03 09:08:46,485 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2020-03-03 09:08:46,771 - INFO - parser - parsing result page https://www.google.com/search?q=cat&ijn=0&start=0&tbs=&tbm=isch
# 2020-03-03 09:08:48,818 - INFO - parser - no more page urls for thread parser-001 to parse
# 2020-03-03 09:08:48,820 - INFO - parser - thread parser-001 exit
# 2020-03-03 09:08:51,490 - INFO - downloader - no more download task for thread downloader-001
# 2020-03-03 09:08:51,491 - INFO - downloader - thread downloader-001 exit
# 2020-03-03 09:08:51,494 - INFO - icrawler.crawler - Crawling task done!

# %%
# !pip install google_images_download

# %%
from google_images_download import google_images_download   #importing the library

response = google_images_download.googleimagesdownload()   #class instantiation

arguments = {"keywords":"Polar bears,baloons,Beaches","limit":20,"print_urls":True}   #creating list of arguments
paths = response.download(arguments)   #passing the arguments to the function
print(paths)
# Out:
# Item no.: 1 --> Item name = Polar bears
# Evaluating...
# Starting Download...
#
#
# Unfortunately all 20 could not be downloaded because some images were not downloadable. 0 is all we got for this search filter!
#
# Errors: 0
#
#
# Item no.: 2 --> Item name = baloons
# Evaluating...
# Starting Download...
#
#
# Unfortunately all 20 could not be downloaded because some images were not downloadable. 0 is all we got for this search filter!
#
# Errors: 0
#
#
# Item no.: 3 --> Item name = Beaches
# Evaluating...
# Starting Download...
#
#
# Unfortunately all 20 could not be downloaded because some images were not downloadable. 0 is all we got for this search filter!
#
# Errors: 0
#
# ({'Polar bears': [], 'baloons': [], 'Beaches': []}, 0)
