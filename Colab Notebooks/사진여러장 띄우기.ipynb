# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import glob

# %%
len(os.listdir("img"))
print(os.listdir("img"))
# Out:
# ['1.201910210959082880_1.jpg', '2.20191022065958733884_0_795_500.jpg', '6._EA_B3_B5_EC_9C_A0_22.JPG', '.ipynb_checkpoints', '5.2018080301375_0.jpg', '4.3717694133_QR14Ma50_1.jpg', 'ert.jpg', '3.97652494.2.jpg']

# %%
img_list = glob.glob('/content/img/*.jpg')
imgs=[]

plt.figure(figsize=(16,8))
for i, img_path in enumerate(img_list):
  img = cv2.imread(img_path)
  plt.subplot(1,len(img_list), i+1)
  img_resize = cv2.resize(img, (480, 600))
  cv2.imwrite('/content/tt/*.jpg', img_resize)
  plt.imshow(cv2.cvtColor(img_resize, cv2.COLOR_BGR2RGB))
  imgs.append(img_resize)

# %%
# Out:
# (600, 480, 3)
